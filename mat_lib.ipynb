# %%
# !pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\rakes\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
price=[24,30,20,45,50,70]
year=[2001,2002,2003,2004,2005,2006]
plt.plot(year,price)
plt.show()

# %%
months=['jan','feb','mar','apr','may','jun','jul','ag','sep','oct','nov','dec']
stock=[20,30,30,40,20,50,60,10,20,40,70,100]
plt.plot(months,stock)
plt.show()

# %%
months=['jan','feb','mar','apr','may','jun','jul','ag','sep','oct','nov','dec']
stock=[20,30,31,40,20,50,60,10,20,40,70,100]
plt.plot(months,stock)
plt.show()

# %%
children=[10,25,30,10,40]
colors=["red","blue","green","yellow","pink"]
plt.bar(colors,children,color="green")
plt.show()

# %%
months=['jan','feb','mar','apr','may','jun','jul','ag','sep','oct','nov','dec']
stock=[20,30,30,40,20,50,60,10,20,40,70,100]
plt.bar(months,stock,color="red")
plt.show()

# %%
children=[10,25,30,10,40]
colors=["red","blue","green","yellow","pink"]
plt.bar(colors,children,color="green")
plt.xlabel("colores")
plt.ylabel("children")
plt.title("simpple bar chart")
plt.legend(colors)
plt.show()

# %%
data=[40,44,45,48,9]
sub=["e","soc","mat","phy","chem"]
explode=(0,0,0.2,0,0)
plt.pie(data,labels=sub ,autopct="%1.1f%%" explode=explode)
plt.title("piechart")
plt.show()
# Out:
#   Cell In[30], line 4
#     plt.pie(data,labels=sub ,autopct="%1.1f%%" explode=explode)
#                                      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
exam_score=[87,76,78,98,56,65,100,99,89,90,90]
